# %% [markdown]
# # 02. Sky Map & Astronomical Coordinates
#
# Transform equatorial/galactic coordinates and generate an all-sky observational map using Astropy (e.g. Mollweide projection).
#
# > **Note:** Implementation will be added progressively during Phase 1.
